# %%
import pandas as pd
from selenium import webdriver
import time
import datetime
#
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
#
import bs4
import urllib
#
import random

# %% [markdown]
# ## LOL

# %%
driver = webdriver.Chrome()
driver.get('https://leagueoflegends.fandom.com/wiki/List_of_champions/Base_statistics')
driver.maximize_window()

# %%
df = pd.DataFrame([x.split(' ') for x in driver.find_element(By.XPATH, '/html/body/div[4]/div[4]/div[3]/main/div[3]/div[2]/div[1]/div[1]/div/div').text.split('\n')]).dropna(how = 'all', axis = 1)
headers = [x for x in df.iloc[0].to_list() if x != None]
df = df.drop(0, axis = 0)
df = df.drop(0, axis = 1)
df = df.reset_index(drop = True)

for row in range(len(df)):
    
    if df[21][row] != None:
        
        l_temp = [x for x in df.loc[row].to_list() if x != None]
        l_temp[0] = l_temp[0] + ' ' + l_temp[1] + ' ' + l_temp[2]
        del(l_temp[1])
        del(l_temp[2])
        l_temp.append(None)
        l_temp.append(None)

        df.loc[row] = l_temp
        
        pass
        
    elif df[21][row] == None and df[20][row] != None:
        
        l_temp = [x for x in df.loc[row].to_list() if x != None]
        l_temp[0] = l_temp[0] + ' ' + l_temp[1]
        del(l_temp[1])
        l_temp.append(None)
        l_temp.append(None)
        df.loc[row] = l_temp

df = df.drop([20, 21], axis = 1)
 
df.columns = headers

df
# Out:
#     Champions   HP   HP+   HP5   HP5+   MP    MP+    MP5   MP5+  AD    AD+  \
# 0      Aatrox  650  +114     3     +1    0     +0      0     +0  60     +5
# 1        Ahri  590   +96   2.5   +0.6  418    +25      8   +0.8  53     +3
# 2       Akali  570  +119     9   +0.9  200     +0     50     +0  62   +3.3
# 3      Akshan  630  +107  3.75  +0.65  350    +40    8.2   +0.7  52     +3
# 4     Alistar  685  +120   8.5  +0.85  350    +40    8.5   +0.8  62  +3.75
# ..        ...  ...   ...   ...    ...  ...    ...    ...    ...  ..    ...
# 162      Zeri  630  +110  3.25   +0.7  250    +45      6   +0.8  53   +1.3
# 163     Ziggs  606  +106   6.5   +0.6  480  +23.5      8   +0.8  54   +3.1
# 164    Zilean  574   +96   5.5   +0.5  452    +50  11.35   +0.8  52     +3
# 165       Zoe  630  +106   7.5   +0.6  425    +25      8  +0.65  58   +3.3
# 166      Zyra  574   +93   5.5   +0.5  418    +25     13   +0.4  53   +3.2
#
#         AS      AS+  AR    AR+  MR    MR+   MS Range
# 0    0.651    +2.5%  38  +4.45  32  +2.05  345   175
# 1    0.668      +2%  21   +4.7  30   +1.3  330   550
# 2    0.625    +3.2%  23   +4.7  37  +2.05  345   125
# 3    0.638      +4%  26   +4.7  30   +1.3  330   500
# 4    0.625  +2.125%  47   +4.7  32  +2.05  330   125
# ..     ...      ...  ..    ...  ..    ...  ...   ...
# 162  0.658      +2%  24   +4.2  30   +1.3  330   500
# 163  0.656      +2%  22   +4.5  30   +1.3  325   550
# 164  0.625   +2.13%  24     +5  30   +1.3  335   550
# 165  0.625    +2.5%  21   +4.7  30   +1.3  340   550
# 166  0.681   +2.11%  29   +4.2  30   +1.3  340   575
#
# [167 rows x 19 columns]

# %%
df.to_csv('export_lol_champs.csv')

# %% [markdown]
# ## TFT

# %%
# url_landing = "https://leagueoflegends.fandom.com/wiki/List_of_champions_in_Dawn_of_Heroes_(Teamfight_Tactics)"
